# %%
# Import python libraries
import pandas as pd
import hvplot.pandas
import holoviews as hv
import osmnx as osm
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="e9fa6183-0dbc-4a9f-99a8-0ca874ef05fb" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Search for boundary using OSM

UAlg_boundary = osm.geocode_to_gdf(

                        "W130097717",

                        by_osmid=True

)

 

UAlg_boundary
# Out:
#                                             geometry  bbox_north  bbox_south  \
# 0  POLYGON ((-7.97810 37.04292, -7.97123 37.04213...   37.047054   37.042127
#
#    bbox_east  bbox_west   place_id osm_type     osm_id        lat       lon  \
# 0  -7.970205  -7.978099  296972392      way  130097717  37.044672 -7.973045
#
#      class        type  place_rank  importance addresstype  \
# 0  amenity  university          30    0.000064     amenity
#
#                                            name  \
# 0  Universidade do Algarve - Campus de Gambelas
#
#                                         display_name
# 0  Universidade do Algarve - Campus de Gambelas, ...

# %%
UAlg_boundary.plot()
# Out:
# <Axes: >
